# %% [markdown]
# # Laboratorio 1: Jupyter, Git, GitHub y Tooling Reproducible 👾
#
# MDS7202: Laboratorio de Programación Científica para Ciencia de Datos - Otoño 2026
#
# ---

# %% [markdown]
# <center> <img src=https://miro.medium.com/max/1388/1*v6CPVlDCr5kdIpj7O6D7VA.gif width=400 alt="Animación de bienvenida a Jupyter y Git"> </center>
#
# ### Cuerpo Docente
#
# - Profesor: Pablo Badilla y Ignacio Nuñez
# - Ayudantes: TBD
#
# ### Objetivos del lab
#
# - Comprender cómo se usa Jupyter para leer y documentar un laboratorio.
# - Leer y escribir documentos técnicos con Markdown.
# - Comprender y aplicar conceptos de control de versiones con Git: commits, ramas, merge y resolución de conflictos.
# - Familiarizarse con el flujo colaborativo de GitHub: repositorios, Pull Requests y revisión de cambios.
# - Configurar un entorno reproducible usando `uv`, `ruff` y `pre-commit`.
# - Verificar la calidad del proyecto mediante validaciones locales y CI.

# %% [markdown]
# ### Equipo: SUPER IMPORTANTE - notebooks sin nombre no serán revisados
#
# - Nombre de alumno 1: Emilio Torres Berríos
# - Nombre de alumno 2: Alexander Sacchetti Villalobos

# %% [markdown]
# ## Jupyter
#
# <!-- DEFINICIÓN -->
# <div style="padding:16px 20px; margin:16px 0; border-left:4px solid #3fb950; background:rgba(63,185,80,.12); color:inherit; border-radius:4px;">
#
#   <strong style="display:block; margin-bottom:8px;">📖 Definición</strong>
#   Jupyter es un entorno interactivo para combinar texto, código y resultados en un mismo documento. Un notebook está formado por celdas y utiliza un kernel para ejecutar el código. Las celdas Markdown contienen texto informativo y las celdas de código permiten ejecutar pequeños experimentos paso a paso.
# </div>
#
# En ciencia de datos, un notebook puede servir para explorar datos, documentar un experimento, mostrar resultados y dejar una explicación reproducible. El notebook no reemplaza necesariamente a un módulo de código, pero ayuda a comunicar el razonamiento detrás del trabajo.

# %% [markdown]
# ## Usar un notebook en VS Code
#
# Para trabajar con este archivo en VS Code:
#
# 1. Instala la extensión **Jupyter** de Microsoft.
# 2. Abre el archivo `.ipynb`.
#
# - El **modo edición** permite escribir dentro de una celda.
# - El **modo comando** permite seleccionar celdas y ejecutar acciones sobre ellas.
#
#
# Presiona `Esc` para pasar al modo comando y `Enter` para volver a editar la celda seleccionada.

# %% [markdown]
# ## Atajos útiles para notebooks
#
# | Atajo | Acción |
# |---|---|
# | `Ctrl + Enter` | Ejecutar la celda manteniendo la selección |
# | `Alt + Enter` | Ejecutar la celda e insertar una nueva debajo |
# | `Esc` | Pasar al modo comando |
# | `Enter` | Editar la celda seleccionada |
# | `A` | Insertar una celda arriba |
# | `B` | Insertar una celda abajo |
# | `M` | Convertir la celda a Markdown |
# | `Y` | Convertir la celda a código |
# | `DD` | Eliminar la celda seleccionada |
# | `Z` | Deshacer la eliminación de una celda |
#
# En macOS, usa `Cmd` cuando el atajo indique `Ctrl`.
#
# Comprueba los atajos disponibles desde la paleta de comandos de VS Code si tu configuración es distinta.

# %% [markdown]
# <!-- PREGUNTA -->
# <div style="padding:16px 20px; margin:16px 0; border-left:4px solid #58a6ff; background:rgba(88,166,255,.12); color:inherit; border-radius:4px;">
#
#   <strong style="display:block; margin-bottom:8px;">❓ Pregunta</strong>
#   ¿Qué diferencia hay entre una celda Markdown, una celda de código y el kernel de un notebook?
# </div>

# %% [markdown]
# <code>Escribe tus respuestas aquí:</code> Una celda Markdown es la que contiene el texto en formato en MD y no lo "corre" solo lo renderiza en ese formato. Una celda de código es la que contiene algún lenguaje de programación y que manda el código al kernel para ejecutarlo y muestra la salida justo debajo. El kernel de un notebook es el que ejecuta el código y guarda el estado de las variables para poder ser usadas en celdas posteriores.

# %% [markdown]
# ## Cómo leer los laboratorios
#
# Los laboratorios mezclarán explicaciones breves con actividades prácticas. Las cajas de colores presentan conceptos, recomendaciones, advertencias o preguntas de comprensión.
#
# Las preguntas siempre aparecen en una celda independiente. La celda inmediatamente siguiente queda reservada para responder.
# En este laboratorio las respuestas son Markdown; en laboratorios futuros también encontrarán celdas preparadas para responder preguntas de código.
#
# Los comandos deben ejecutarse en la terminal, salvo que se indique explícitamente lo contrario.
# Cuando una instrucción diga “en la raíz del repositorio”, verifica la ruta actual antes de ejecutarla.

# %% [markdown]
# ---
#
# # Sección 1: GitHub y Git 👾

# %% [markdown]
# ## Git
#
# <!-- DEFINICIÓN -->
# <div style="padding:16px 20px; margin:16px 0; border-left:4px solid #3fb950; background:rgba(63,185,80,.12); color:inherit; border-radius:4px;">
#
#   <strong style="display:block; margin-bottom:8px;">📖 Definición</strong>
#   Git es un sistema distribuido de control de versiones. Registra cambios en un historial de commits y permite trabajar en ramas separadas antes de integrar los cambios. Cada integrante puede tener una copia local del historial y sincronizarla con uno o más repositorios remotos.
# </div>

# %% [markdown]
# ## Repositorio
#
# <!-- DEFINICIÓN -->
# <div style="padding:16px 20px; margin:16px 0; border-left:4px solid #3fb950; background:rgba(63,185,80,.12); color:inherit; border-radius:4px;">
#
#   <strong style="display:block; margin-bottom:8px;">📖 Definición</strong>
#   Un repositorio es una carpeta administrada por Git que contiene los archivos del proyecto y el historial de cambios. Puede ser local, cuando está en tu equipo, o remoto, cuando está alojado en un servicio como GitHub.
# </div>
#
# Un repositorio no es solamente una carpeta compartida: también conserva quién cambió cada archivo, cuándo lo hizo y qué diferencias introdujo.

# %% [markdown]
# <!-- PREGUNTA -->
# <div style="padding:16px 20px; margin:16px 0; border-left:4px solid #58a6ff; background:rgba(88,166,255,.12); color:inherit; border-radius:4px;">
#
#   <strong style="display:block; margin-bottom:8px;">❓ Preguntas</strong>
#   1. ¿Qué información conserva Git además de los archivos actuales?
#   2. ¿Cuál es la diferencia entre un repositorio local y uno remoto?
# </div>

# %% [markdown]
# <code>Escribe tus respuestas aquí:</code>
# 1. Conserva también quién hizo los cambios, la fecha y el historial de los commits.
# 2. Local es cuando está alojado en tu equipo y remoto cuando está alojado en un servidor.

# %% [markdown]
# ## Configuración inicial de GitHub CLI y Git
#
# Antes de comenzar el laboratorio, crea una cuenta de GitHub si aún no tienes una e instala GitHub CLI. La identidad permite que Git atribuya correctamente los commits y `gh` permite trabajar con GitHub desde la terminal.
#
# ### Windows
#
# ```bash
# winget install --id GitHub.cli
# ```
#
# ### Linux Debian/Ubuntu
#
# ```bash
# sudo apt install gh
# ```
#
# ### macOS
#
# ```bash
# brew install gh
# ```
#
# Si usas otra distribución o no tienes disponible el gestor de paquetes anterior, revisa la página oficial de instalación de GitHub CLI: [cli.github.com](https://cli.github.com/).

# %% [markdown]
# ### Autenticar GitHub CLI y configurar Git
#
# Autentícate con GitHub y configura tu identidad de Git:
#
# ```bash
# gh auth login
# git config --global user.name "Nombre Apellido"
# git config --global user.email "correo@uchile.cl"
# ```
#
# Verifica que la autenticación funcione:
#
# ```bash
# gh auth status
# ```

# %% [markdown]
# ## Markdown para documentación técnica
#
# <!-- DEFINICIÓN -->
# <div style="padding:16px 20px; margin:16px 0; border-left:4px solid #3fb950; background:rgba(63,185,80,.12); color:inherit; border-radius:4px;">
#
#   <strong style="display:block; margin-bottom:8px;">📖 Definición</strong>
#   Markdown es un lenguaje de marcado liviano que permite escribir texto estructurado usando caracteres simples. Luego, ese texto puede convertirse en títulos, listas, enlaces, tablas, imágenes y bloques de código.
# </div>
#
# En ciencia de datos aparece en los `README.md`, notebooks, reportes de experimentos, documentación de datasets y Pull Requests. La idea es que otras personas puedan entender qué hace un proyecto, cómo ejecutarlo y qué decisiones se tomaron.

# %% [markdown]
# ### Elementos frecuentes de Markdown
#
# | Elemento | Escritura | Uso |
# |---|---|---|
# | Título | `# Título` | Organizar secciones |
# | Énfasis | `**importante**` | Destacar información |
# | Lista | `- elemento` | Enumerar ideas o pasos |
# | Enlace | `[texto](https://ejemplo.com)` | Referenciar recursos |
# | Imagen | `![alt](imagen.png)` | Incorporar una imagen |
# | Código | `git status` | Mostrar un comando |
# | Bloque de código | Tres backticks | Mostrar un script completo |
# | Tabla | Filas separadas por `|` | Comparar información |
#
# El texto que escribes es la fuente Markdown; la vista previa muestra su representación renderizada. Los alerts de este laboratorio combinan una celda Markdown con HTML para controlar mejor su presentación visual.
#
# <!-- DEFINICIÓN -->
# <div style="padding:16px 20px; margin:16px 0; border-left:4px solid #3fb950; background:rgba(63,185,80,.12); color:inherit; border-radius:4px;">
#
#   <strong style="display:block; margin-bottom:8px;">📖 Definición</strong>
#   Una cheat sheet es una guía breve de consulta rápida que reúne sintaxis y ejemplos frecuentes. Puedes consultar la [Markdown Guide Cheat Sheet](https://www.markdownguide.org/cheat-sheet/) cuando no recuerdes una construcción.
# </div>

# %% [markdown]
# <!-- PREGUNTA -->
# <div style="padding:16px 20px; margin:16px 0; border-left:4px solid #58a6ff; background:rgba(88,166,255,.12); color:inherit; border-radius:4px;">
#
#   <strong style="display:block; margin-bottom:8px;">❓ Preguntas</strong>
#
#   1. ¿Qué es un lenguaje de marcado?
#   2. ¿Qué es HTML?
#   3. ¿Qué diferencia hay entre escribir `**texto**` y ver el texto en negrita?
#   4. ¿En qué archivo del perfil personal usarás Markdown?
# </div>

# %% [markdown]
# <code>Escribe tus respuestas aquí:</code>
# 1. Es un sistema que usa etiquetas o símbolos para indicar cómo debe estructurarse o mostrarse el texto (títulos, listas, énfasis, etc.), separando el contenido de su presentación, como por ej. HTML.
#
# 2. Es el lenguaje de marcado estándar para crear páginas web. Usa etiquetas para estructurar el contenido que muestra el navegador.
#
# 3. `**texto**` es el **código fuente** (la sintaxis Markdown que se escribe); mientras que **texto** es el **resultado renderizado** que se ve cuando ese código se procesa y se muestra.
#
# 4. En el `README.md`.

# %% [markdown]
# ## GitHub
#
# <!-- DEFINICIÓN -->
# <div style="padding:16px 20px; margin:16px 0; border-left:4px solid #3fb950; background:rgba(63,185,80,.12); color:inherit; border-radius:4px;">
#
#   <strong style="display:block; margin-bottom:8px;">📖 Definición</strong>
#   GitHub es una plataforma para alojar repositorios Git y colaborar sobre ellos. Ofrece permisos, revisión de cambios, Pull Requests, Issues y GitHub Actions.
# </div>
#
# Git y GitHub no son lo mismo: Git administra el historial local y GitHub aloja repositorios remotos y ofrece herramientas de colaboración. GitHub Actions permite ejecutar validaciones automáticamente en servidores remotos.

# %% [markdown]
# <!-- WARNING -->
# <div style="padding:16px 20px; margin:16px 0; border-left:4px solid #d29922; background:rgba(210,153,34,.12); color:inherit; border-radius:4px;">
#
#   <strong style="display:block; margin-bottom:8px;">⚠️ Warning</strong>
#   Nunca publiques contraseñas, tokens, llaves privadas, datos personales innecesarios o datasets confidenciales en un repositorio público. Borrar un archivo después no garantiza que desaparezca del historial.
# </div>

# %% [markdown]
# ## Pull Requests
#
# <!-- DEFINICIÓN -->
# <div style="padding:16px 20px; margin:16px 0; border-left:4px solid #3fb950; background:rgba(63,185,80,.12); color:inherit; border-radius:4px;">
#
#   <strong style="display:block; margin-bottom:8px;">📖 Definición</strong>
#   Un Pull Request (PR) propone integrar los cambios de una rama de trabajo en una rama base. El PR muestra el diff, permite revisar comentarios y puede ejecutar validaciones automáticas antes del merge.
# </div>
#
# En este laboratorio, `perfil-inicial` es la rama de trabajo y `main` es la rama base. El mismo flujo se usa en equipos de datos para revisar transformaciones, notebooks, pipelines y configuraciones.

# %% [markdown]
# <!-- IMPORTANTE -->
# <div style="padding:16px 20px; margin:16px 0; border-left:4px solid #8957e5; background:rgba(137,87,229,.12); color:inherit; border-radius:4px;">
#
#   <strong style="display:block; margin-bottom:8px;">📌 Importante</strong>
#   Un PR no reemplaza a Git: Git crea los commits y ramas; GitHub presenta esos cambios para que otras personas los revisen, validen y mezclen. Un PR también es útil dentro de un repositorio personal porque deja trazabilidad del cambio.
# </div>

# %% [markdown]
# <!-- PREGUNTA -->
# <div style="padding:16px 20px; margin:16px 0; border-left:4px solid #58a6ff; background:rgba(88,166,255,.12); color:inherit; border-radius:4px;">
#
#   <strong style="display:block; margin-bottom:8px;">❓ Preguntas</strong>
#   1. ¿Qué branch es la base del PR del perfil? R: la main que es la branch principal a la que se fusionará el trabajo
#   2. ¿Qué branch contiene el trabajo? R: la branch perfil-inicial
#   3. ¿Qué información debería revisar otra persona antes de aprobarlo? R: Que el README esté bien y coincida con los cambios que se dicen en el PR.
# </div>

# %% [markdown]
# <code>Escribe tus respuestas aquí:</code>

# %% [markdown]
# ### Parte 1: Creando y actualizando una presentación personal (1.5 pts)

# %% [markdown]
# Para empezar a soltar las manos con Git y GitHub, crea un repositorio personal con una presentación. El repositorio debe llevar tu nombre de usuario.
#
# El repositorio debe contener un breve resumen de quién eres, tus gustos, experiencias y cualquier otro detalle que consideres relevante.
#
# ### Crear el repositorio personal
#
# Cuenta con una cuenta de GitHub y ejecuta:
#
# ```bash
# gh repo create [usuario] --public --add-readme --clone
# cd [usuario]
# ```
#
# Reemplaza `[usuario]` por tu nombre de usuario real.

# %% [markdown]
# ### Crear la rama y editar el perfil
#
# Crea una rama para actualizar el perfil y modifica `README.md` con la información que desees compartir:
#
# ```bash
# git checkout -b perfil-inicial
# ```
#
# Puedes guiarte por esta [presentación](https://github.com/pbadillatorrealba/pbadillatorrealba) o por los templates de [Awesome GitHub Profile README](https://durgeshsamariya.github.io/awesome-github-profile-readme-templates/#/).
#
# Incluye títulos, listas, enlaces o imágenes de Markdown que ayuden a presentar tu perfil.

# %% [markdown]
# ### Subir los cambios y abrir el Pull Request
#
# Registra los cambios y sube la rama:
#
# ```bash
# git add README.md
# git commit -m "feat: agregar perfil personal"
# git push -u origin perfil-inicial
# ```
#
# Luego abre el Pull Request desde la interfaz gráfica de GitHub:
#
# 1. Entra al repositorio personal.
# 2. Selecciona **Compare & pull request**.
# 3. Elige `main` como branch base y `perfil-inicial` como branch de trabajo.
# 4. Completa el template de Pull Request.
# 5. Crea y mezcla el Pull Request.
#
# La información del perfil debe llegar a `main` mediante el Pull Request, no mediante un commit directo.

# %% [markdown]
# ### Entregables del perfil personal
#
# - Enlace al repositorio personal.
# - Enlace al Pull Request que actualiza el perfil.
#
# IMPORTANTE: DEBEN ADJUNTAR AMBOS ENLACES POR PERSONA.
#
# <code>Link Repositorio Personal 1:</code> https://github.com/AlexanderSV25/AlexanderSV25
#
# <code>Link Pull Request Personal 1:</code> https://github.com/AlexanderSV25/AlexanderSV25/pull/2
#
# <code>Link Repositorio Personal 2:</code> https://github.com/emiliouch/emiliouch
#
# <code>Link Pull Request Personal 2:</code> https://github.com/emiliouch/emiliouch/pull/1

# %% [markdown]
# ## Entorno virtual
#
# <!-- DEFINICIÓN -->
# <div style="padding:16px 20px; margin:16px 0; border-left:4px solid #3fb950; background:rgba(63,185,80,.12); color:inherit; border-radius:4px;">
#
#   <strong style="display:block; margin-bottom:8px;">📖 Definición</strong>
#   Un entorno virtual es una instalación aislada de Python y sus paquetes para un proyecto. Permite que dos proyectos usen versiones distintas sin modificar la instalación global del equipo. En este repositorio el entorno se encuentra en `.venv/`.
# </div>
#
# El intérprete, los paquetes instalados y la carpeta `.venv/` forman parte del entorno de trabajo local. El entorno se puede recrear cuando existe una declaración de dependencias reproducible.

# %% [markdown]
# <!-- WARNING -->
# <div style="padding:16px 20px; margin:16px 0; border-left:4px solid #d29922; background:rgba(210,153,34,.12); color:inherit; border-radius:4px;">
#
#   <strong style="display:block; margin-bottom:8px;">⚠️ Warning</strong>
#   `.venv/` es un artefacto local y no debe versionarse. Instalar paquetes globalmente puede producir conflictos entre proyectos y hacer difícil reproducir el laboratorio.
# </div>

# %% [markdown]
# <!-- PREGUNTA -->
# <div style="padding:16px 20px; margin:16px 0; border-left:4px solid #58a6ff; background:rgba(88,166,255,.12); color:inherit; border-radius:4px;">
#
#   <strong style="display:block; margin-bottom:8px;">❓ Pregunta</strong>
#   ¿Por qué no deberías versionar la carpeta `.venv/`?
# </div>

# %% [markdown]
# <code>Escribe tus respuestas aquí:</code> Porque puede producir conflictos entre proyectos y hacer difícil reproducir los laboratorios.

# %% [markdown]
# ## `pyproject.toml`
#
# <!-- DEFINICIÓN -->
# <div style="padding:16px 20px; margin:16px 0; border-left:4px solid #3fb950; background:rgba(63,185,80,.12); color:inherit; border-radius:4px;">
#
#   <strong style="display:block; margin-bottom:8px;">📖 Definición</strong>
#   `pyproject.toml` es el archivo de configuración central de un proyecto Python. Puede declarar metadatos, versión de Python, dependencias principales, dependencias de desarrollo y configuración de herramientas como Ruff.
# </div>
#
# En este proyecto, `[project].dependencies` contiene las dependencias principales y `[dependency-groups].dev` contiene herramientas de desarrollo. `pyproject.toml` declara restricciones; `uv.lock` registra una resolución concreta de esas restricciones para favorecer la reproducibilidad.

# %% [markdown]
# <!-- PREGUNTA -->
# <div style="padding:16px 20px; margin:16px 0; border-left:4px solid #58a6ff; background:rgba(88,166,255,.12); color:inherit; border-radius:4px;">
#
#   <strong style="display:block; margin-bottom:8px;">❓ Preguntas</strong>
#   1. ¿Qué información se declara en `pyproject.toml`?
#   2. ¿Qué información adicional fija `uv.lock`?
# </div>

# %% [markdown]
# <code>Escribe tus respuestas aquí:</code>
# 1.  Metadatos, versión de Python, dependencias principales, dependencias de desarrollo y configuración de herramientas como Ruff.
# 2. Registra una resolución concreta de las restricciones para favorecer la reproducibilidad.

# %% [markdown]
# ## `uv`
#
# <!-- DEFINICIÓN -->
# <div style="padding:16px 20px; margin:16px 0; border-left:4px solid #3fb950; background:rgba(63,185,80,.12); color:inherit; border-radius:4px;">
#
#   <strong style="display:block; margin-bottom:8px;">📖 Definición</strong>
#   `uv` es una herramienta para crear entornos, resolver dependencias, mantener archivos de lock y ejecutar comandos dentro del entorno del proyecto.
# </div>
#
# | Comando | Propósito |
# |---|---|
# | `uv sync` | Sincronizar el entorno con la configuración del proyecto |
# | `uv run` | Ejecutar un comando dentro del entorno del proyecto |
# | `uv add` | Agregar una dependencia y actualizar la configuración |
# | `uv lock` | Resolver y actualizar `uv.lock` |
#
# En este laboratorio se usará `uv sync --locked --all-groups`: `--locked` exige que el lock sea consistente y `--all-groups` instala también las herramientas de desarrollo.

# %% [markdown]
# <!-- PREGUNTA -->
# <div style="padding:16px 20px; margin:16px 0; border-left:4px solid #58a6ff; background:rgba(88,166,255,.12); color:inherit; border-radius:4px;">
#
#   <strong style="display:block; margin-bottom:8px;">❓ Preguntas</strong>
#   1. ¿Qué diferencia hay entre `uv sync` y `uv run`?
#   2. ¿Por qué este laboratorio usa la opción `--locked`?
# </div>

# %% [markdown]
# <code>Escribe tus respuestas aquí:</code>
# 1. `uv sync` sincroniza el entorno con la configuración del proyecto, mientras que `uv run` ejecuta un comando dentro del entorno del proyecto.
# 2. Para exigir que el lock sea consistente.

# %% [markdown]
# ## Ruff
#
# <!-- DEFINICIÓN -->
# <div style="padding:16px 20px; margin:16px 0; border-left:4px solid #3fb950; background:rgba(63,185,80,.12); color:inherit; border-radius:4px;">
#
#   <strong style="display:block; margin-bottom:8px;">📖 Definición</strong>
#   Ruff es una herramienta rápida para revisar y formatear código Python. `ruff check` busca problemas según las reglas configuradas y `ruff format` aplica o comprueba un formato consistente.
# </div>
#
# Encontrar problemas y formatear archivos son operaciones relacionadas, pero no idénticas. Las reglas actuales del repositorio viven en `pyproject.toml` y deben copiarse sin reemplazarlas por una lista reducida.

# %% [markdown]
# ## pre-commit
#
# <!-- DEFINICIÓN -->
# <div style="padding:16px 20px; margin:16px 0; border-left:4px solid #3fb950; background:rgba(63,185,80,.12); color:inherit; border-radius:4px;">
#
#   <strong style="display:block; margin-bottom:8px;">📖 Definición</strong>
#   `pre-commit` ejecuta hooks locales antes de crear un commit. Permite encontrar problemas temprano y mantener el mismo conjunto de revisiones en todo el equipo.
# </div>
#
# La configuración de los hooks está en `.pre-commit-config.yaml`. Después de instalar las dependencias, se habilita con:
#
# ```bash
# uv run pre-commit install
# ```

# %% [markdown]
# ## CI
#
# <!-- DEFINICIÓN -->
# <div style="padding:16px 20px; margin:16px 0; border-left:4px solid #3fb950; background:rgba(63,185,80,.12); color:inherit; border-radius:4px;">
#
#   <strong style="display:block; margin-bottom:8px;">📖 Definición</strong>
#   CI, o integración continua, ejecuta validaciones automáticamente en un servidor remoto cuando se suben cambios o se abre un Pull Request.
# </div>

# %% [markdown]
# <!-- TIP -->
# <div style="padding:16px 20px; margin:16px 0; border-left:4px solid #2f81f7; background:rgba(47,129,247,.12); color:inherit; border-radius:4px;">
#
#   <strong style="display:block; margin-bottom:8px;">💡 Tip</strong>
#   Prefiere `uv run` para ejecutar las herramientas en el entorno correcto, aunque no hayas activado manualmente `.venv/`.
# </div>

# %% [markdown]
# <!-- IMPORTANTE -->
# <div style="padding:16px 20px; margin:16px 0; border-left:4px solid #8957e5; background:rgba(137,87,229,.12); color:inherit; border-radius:4px;">
#
#   <strong style="display:block; margin-bottom:8px;">📌 Importante</strong>
#   No edites manualmente `uv.lock` para resolver una dependencia. Cambia `pyproject.toml` y deja que `uv lock` genere una nueva resolución.
# </div>

# %% [markdown]
# <!-- PREGUNTA -->
# <div style="padding:16px 20px; margin:16px 0; border-left:4px solid #58a6ff; background:rgba(88,166,255,.12); color:inherit; border-radius:4px;">
#
#   <strong style="display:block; margin-bottom:8px;">❓ Preguntas</strong>
#   1. ¿Qué herramienta ejecuta revisiones antes del commit?
#   2. ¿Qué archivo contiene las reglas de Ruff?
#   3. ¿Qué archivo contiene el workflow de CI?
# </div>

# %% [markdown]
# <code>Escribe tus respuestas aquí:</code>
# 1. pre-commit
# 2. pyproject.toml
# 3. .github/workflows/

# %% [markdown]
# ## Configuración reproducible del entorno del curso
#
# En esta sección revisaremos la configuración del repositorio en el que acumularán los laboratorios. La aplicarán al repositorio del curso cuando lo creen en la sección final. Usen como fuente de verdad el `pyproject.toml` entregado por el curso. No reemplacen sus dependencias por una lista más pequeña.
#
# <!-- WARNING -->
# <div style="padding:16px 20px; margin:16px 0; border-left:4px solid #d29922; background:rgba(210,153,34,.12); color:inherit; border-radius:4px;">
#
#   <strong style="display:block; margin-bottom:8px;">⚠️ Warning</strong>
#   Antes de ejecutar estos comandos, confirma que estás en la raíz del repositorio del curso. De lo contrario, `uv`, pre-commit y las rutas relativas podrían operar sobre otro proyecto o fallar de forma confusa.
# </div>

# %% [markdown]
# ### Dependencias principales
#
# La sección `[project].dependencies` contiene las dependencias principales del curso:
#
# ```toml
# dependencies = [
#     "fastapi>=0.141.1",
#     "fastparquet>=2026.5.0",
#     "ipykernel>=7.3.0",
#     "ipython>=9.15.0",
#     "jupyterlab>=4.6.2",
#     "lightgbm>=4.7.0",
#     "matplotlib>=3.11.1",
#     "missingno>=0.5.2",
#     "mlflow>=3.14.0",
#     "narwhals>=2.24.0",
#     "nltk>=3.10.0",
#     "numba>=0.61",
#     "numpy>=2.4.6",
#     "optuna>=4.9.0",
#     "pandas>=2.3.3",
#     "pillow>=12.3.0",
#     "plotly>=6.9.0",
#     "protobuf>=6.33.6",
#     "scikit-learn>=1.9.0",
#     "seaborn>=0.13.2",
#     "shap>=0.49.1",
#     "tqdm>=4.70.0",
#     "umap-learn>=0.5.12",
#     "xgboost>=3.3.0",
# ]
# ```

# %% [markdown]
# ### Herramientas de desarrollo
#
# Las herramientas se declaran en `[dependency-groups].dev`:
#
# ```toml
# dev = [
#     "pre-commit>=4.6.1",
#     "pyrefly>=1.1.1",
#     "pytest>=9.1.1",
#     "ruff>=0.16.1",
#     "ty>=0.0.65",
# ]
# ```

# %% [markdown]
# ### Reglas de Ruff
#
# Copien también las reglas actuales del archivo del curso:
#
# ```toml
# [tool.ruff]
# line-length = 80
# target-version = "py313"
#
# [tool.ruff.lint]
# select = [
#     "E", "W", "F", "I", "B", "C4", "UP",
#     "SIM", "RUF", "FAST", "YTT", "ASYNC", "DTZ",
#     "PT", "PTH",
# ]
# ignore = [
#     "E501", "B008", "C901", "B018", "RUF003",
#     "F811", "F821",
# ]
# ```

# %% [markdown]
# ### Sincronizar y validar
#
# Después de copiar `pyproject.toml`, `uv.lock`, `.gitignore`, `.pre-commit-config.yaml`, `.github/pull_request_template.md` y `.github/workflows/lint.yml` al repositorio del curso, ejecuten:
#
# ```bash
# uv sync --locked --all-groups
# uv run pre-commit install
# uv run pre-commit run --all-files
# uv run ruff check .
# uv run ruff format --check .
# ```
#
# La CI debe ejecutar las mismas validaciones después de abrir el Pull Request.

# %% [markdown]
# ---
#
# # Sección 2: Práctica de Git 👾

# %% [markdown]
# ## Git: modelo mental
#
# <!-- DEFINICIÓN -->
# <div style="padding:16px 20px; margin:16px 0; border-left:4px solid #3fb950; background:rgba(63,185,80,.12); color:inherit; border-radius:4px;">
#
#   <strong style="display:block; margin-bottom:8px;">📖 Definición</strong>
#   Git trabaja con snapshots y un historial de commits. Una rama es un puntero a una línea de trabajo y `HEAD` indica dónde estás trabajando actualmente.
# </div>
#
# Para entender qué ocurre al ejecutar un comando, distingue cuatro espacios:
#
# ```text
# working tree --git add--> staging area --git commit--> repositorio local
#       ^                         ^                         |
#       |                         |                         | git push
#       +------ git restore       +------ git reset         v
#                                                    repositorio remoto
# ```

# %% [markdown]
# El working tree contiene tus archivos actuales. El staging area contiene los cambios que seleccionaste para el próximo commit. El repositorio local contiene el historial y el remoto permite compartirlo.
#
# Git es útil para versionar código, configuraciones, notebooks y documentación de un proyecto de datos. No reemplaza un sistema de almacenamiento para datasets grandes ni debe usarse para guardar secretos, ambientes virtuales, logs o modelos pesados.

# %% [markdown]
# ## Operaciones principales
#
# | Operación | Para qué sirve |
# |---|---|
# | `git status` | Revisar branch, cambios y conflictos |
# | `git diff` | Inspeccionar cambios todavía no preparados |
# | `git add` | Pasar cambios al staging area |
# | `git commit` | Guardar un snapshot en el historial local |
# | `git log` | Inspeccionar commits, ramas y relaciones |
# | `git branch` | Crear o listar branches |
# | `git checkout` | Cambiar de branch o recuperar archivos |
# | `git fetch` | Descargar referencias remotas sin modificar tu branch |
# | `git pull` | Descargar cambios e integrarlos en la branch actual |
# | `git push` | Publicar commits locales en un remoto |
# | `git merge` | Integrar el historial de otra branch |
# | `git merge --abort` | Cancelar un merge con conflictos |
# | `git blame` | Ver qué commit modificó cada línea |
# | `git restore` | Recuperar o descartar cambios de archivos |
# | `git stash` | Guardar temporalmente cambios sin commit |

# %% [markdown]
# <!-- TIP -->
# <div style="padding:16px 20px; margin:16px 0; border-left:4px solid #2f81f7; background:rgba(47,129,247,.12); color:inherit; border-radius:4px;">
#
#   <strong style="display:block; margin-bottom:8px;">💡 Tip</strong>
#   Ejecuta `git status` antes y después de cada operación importante. Los commits pequeños y descriptivos facilitan revisar experimentos, revertir errores y entender la historia del proyecto.
# </div>
#
# <!-- IMPORTANTE -->
# <div style="padding:16px 20px; margin:16px 0; border-left:4px solid #8957e5; background:rgba(137,87,229,.12); color:inherit; border-radius:4px;">
#
#   <strong style="display:block; margin-bottom:8px;">📌 Importante</strong>
#   `origin/fix-ifs` es una referencia a una branch del remoto `origin`. Después de clonar, puede no existir una branch local llamada `fix-ifs`; por eso se usa explícitamente `git merge origin/fix-ifs`.
# </div>
#
# <!-- CAUTION -->
# <div style="padding:16px 20px; margin:16px 0; border-left:4px solid #f85149; background:rgba(248,81,73,.12); color:inherit; border-radius:4px;">
#
#   <strong style="display:block; margin-bottom:8px;">🛑 Caution</strong>
#   No ejecutes `git reset --hard`, `git clean` o `git push --force` sin entender qué cambios eliminarás o sobrescribirás. En branches compartidas puedes borrar trabajo de otras personas.
# </div>

# %% [markdown]
# <!-- PREGUNTA -->
# <div style="padding:16px 20px; margin:16px 0; border-left:4px solid #58a6ff; background:rgba(88,166,255,.12); color:inherit; border-radius:4px;">
#
#   <strong style="display:block; margin-bottom:8px;">❓ Preguntas</strong>
#   1. ¿Qué espacio modifica `git add`?
#   2. ¿Qué diferencia hay entre `git fetch`, `git pull` y `git push`?
#   3. ¿Por qué `origin/fix-ifs` no equivale necesariamente a una branch local?
# </div>

# %% [markdown]
# <code>Escribe tus respuestas aquí:</code>
# 1. `git add` modifica el **staging area** (índice), moviendo cambios desde el working directory.
#
# 2. `git fetch` descarga cambios del remoto sin mezclarlos; `git pull` descarga y mezcla (`fetch` + `merge`); `git push` envía tus commits locales al remoto.
#
# 3. Porque `origin/fix-ifs` es solo una referencia local al último estado conocido del remoto (se actualiza únicamente con `fetch`/`pull`), no una branch local editable ni el estado real en vivo del remoto.

# %% [markdown]
# ### Parte 1: Trabajando sobre un repositorio externo (1.5 pts)
#
# Tras muchos dolores de cabeza, un grupo de entusiastas académicos decidió aprender sobre Git y así trabajar colaborativamente de forma más ordenada. Los académicos levantaron este [repositorio](https://github.com/MDS7202/lab1). Usando este repositorio, respondan las siguientes preguntas e incluyan los comandos utilizados.
#
# El repositorio conserva las ramas `main`, `fix-ifs` y `new_features`. La rama `fix-ifs` se utilizará como rama remota en el ejercicio de merge.

# %% [markdown]
# ### Inspección inicial
#
# Clona el repositorio e inspecciona sus ramas remotas:
#
# ```bash
# gh repo clone MDS7202/lab1
# cd lab1
# git branch --all
# ```

# %% [markdown]
# <!-- PREGUNTA -->
# <div style="padding:16px 20px; margin:16px 0; border-left:4px solid #58a6ff; background:rgba(88,166,255,.12); color:inherit; border-radius:4px;">
#
#   <strong style="display:block; margin-bottom:8px;">❓ Preguntas</strong>
#   1. ¿Cuál es el objetivo del proyecto?
#   2. ¿Cómo está estructurado?
#   3. ¿Qué función cumple cada componente?
# </div>

# %% [markdown]
# <code>Escribe tus respuestas aquí:</code>
# 1. Es un proyecto para emular los sonidos de animales
# 2. Con 2 módulos main.py y animales.py y el README
# 3. main.py recibe el input y llama a animales.py, que es el que ve si corresponde el string y ejecuta el sonido o el error.

# %% [markdown]
# <!-- PREGUNTA -->
# <div style="padding:16px 20px; margin:16px 0; border-left:4px solid #58a6ff; background:rgba(88,166,255,.12); color:inherit; border-radius:4px;">
#
#   <strong style="display:block; margin-bottom:8px;">❓ Preguntas</strong>
#   1. Identifica los últimos cambios del repositorio y las principales ramas de trabajo.
#   2. ¿Son informativos los commits realizados?
#   3. Incluye los comandos utilizados.
# </div>

# %% [markdown]
# <code>Escribe tus respuestas aquí:</code>
# 1. El historial tiene 4 commits, que divergen en dos ramas: `main` (junto con `origin/main` y `origin/new_features`), cuyo último commit separa el proyecto en módulos, y `origin/fix-ifs`, una rama remota con una corrección que aún no está incorporada en `main`. Localmente solo existe la branch `main`; `fix-ifs` es únicamente una referencia remota, no una branch local.
# 2. Los commits son poco informativos en general. Los mensajes "primer commit" y "fix ifs" no explican qué cambia ni por qué, mientras que el commit que separa el proyecto en módulos es el más claro.
# 3. git log --oneline -10
# git log --oneline --graph --all -20
# git branch
# git log --stat

# %% [markdown]
# <!-- PREGUNTA -->
# <div style="padding:16px 20px; margin:16px 0; border-left:4px solid #58a6ff; background:rgba(88,166,255,.12); color:inherit; border-radius:4px;">
#
#   <strong style="display:block; margin-bottom:8px;">❓ Preguntas</strong>
#   1. Señala el error en el código.
#   2. Identifica a la persona que lo cometió usando `git blame`.
#   3. Incluye el comando utilizado.
# </div>

# %% [markdown]
# <code>Escribe tus respuestas aquí:</code>
# 1. En animales.py, la estructura usa if en cascada para cada animal, pero el else final solo está asociado al último if ('fox'), no a los tres. Entonces al ingresar 'gato', el programa imprima 'miau' correctamente, pero como no entra al if de 'fox', cae igualmente en el else y lanza ValueError('animal no reconocido :('). Debería usarse elif en cada condición para que el else aplique correctamente solo cuando ninguno de los tres coincide.
# 2. Según la salida de git blame animales.py, todas las líneas del archivo pertenecen al mismo commit, hecho por mezosky.
# 3. git blame animales.py

# %% [markdown]
# <!-- PREGUNTA -->
# <div style="padding:16px 20px; margin:16px 0; border-left:4px solid #58a6ff; background:rgba(88,166,255,.12); color:inherit; border-radius:4px;">
#
#   <strong style="display:block; margin-bottom:8px;">❓ Preguntas</strong>
#   1. Realiza un merge de `origin/fix-ifs` con `main`.
#   2. Describe lo que ocurre.
#   3. ¿Qué parte del código podría estar ocasionándolo?
# </div>

# %% [markdown]
# <code>Escribe tus respuestas aquí:</code>
# 2. Auto-merging main.py
# CONFLICT (content): Merge conflict in main.py
# Automatic merge failed; fix conflicts and then commit the result.
# El merge falla con un conflicto de contenido en main.py. Git no puede fusionar automáticamente porque ambas ramas modificaron ese mismo archivo de forma incompatible: en main, main.py solo importa la función animales() desde animales.py (tras el commit que separó el proyecto en módulos), mientras que en origin/fix-ifs la función animales() sigue definida directamente dentro de main.py (esa rama nunca recibió el commit de modularización, ya que ambas divergen desde el mismo commit anterior.
# 1. El bloque completo de main.py: en la versión de main es solo from animales import animales, mientras que en fix-ifs es la definición entera de la función animales() (con la lógica ya corregida usando elif en vez de if). Ambas versiones ocupan el mismo espacio en el archivo, lo que genera el conflicto — la causa raíz es la divergencia de historial: una rama modularizó el código y la otra corrigió el bug sobre la versión antigua sin modularizar.

# %% [markdown]
# <!-- PREGUNTA -->
# <div style="padding:16px 20px; margin:16px 0; border-left:4px solid #58a6ff; background:rgba(88,166,255,.12); color:inherit; border-radius:4px;">
#
#   <strong style="display:block; margin-bottom:8px;">❓ Preguntas</strong>
#   1. Crea una rama nueva y repite el merge.
#   2. Propón una solución conservando la estructura modular.
#   3. Corrige `animales.py`.
#   4. Adjunta el código corregido y señala las líneas modificadas.
# </div>

# %% [markdown]
# <code>Escribe tus respuestas aquí:</code>
# 1. Se creó la rama `resolucion-fix-ifs` desde `main` y se repitió el merge con `git merge origin/fix-ifs`, reproduciendo el mismo conflicto en `main.py` de forma aislada.
#
# 2. La solución consistió en conservar `main.py` con solo el `import` de la función (estructura modular de `main`), y aplicar la corrección lógica del `fix-ifs` directamente dentro de `animales.py`, combinando así la separación en módulos con el fix del bug.
#
# 3. Se corrigió `animales.py` cambiando los `if` en cascada por `elif`, de modo que el `else` final solo se ejecute cuando ningún animal coincide, y no cada vez que no se cumple la última condición.
#
# 4. El código corregido quedó así:
# ```python
# def animales(input):
#     """
#     Como hace el animalito?
#     """
#     if input.lower() == "gato":
#         print("miau")
#     elif input.lower() == "perro":
#         print("guau")
#     elif input.lower() == "fox":
#         print("https://www.youtube.com/watch?v=jofNR_WkoCE")
#     else:
#         raise ValueError("animal no reconocido :(")
# ```
# Las líneas modificadas fueron la del `elif` para `'perro'` y la del `elif` para `'fox'`, que originalmente eran `if`.

# %% [markdown]
# ---
#
# # Sección 3: Repositorio del curso y entrega
#
# Finalmente, habiendo realizado las actividades anteriores, llegó el momento de subir la entrega al repositorio del curso. Esta sección no tiene puntaje, pero es obligatoria en todos los laboratorios. En los siguientes laboratorios deberán repetir este flujo para ejercitar el trabajo con Git y GitHub.

# %% [markdown]
# ## Crear el repositorio del curso
#
# Crea un repositorio para acumular las entregas del curso. Puedes hacerlo desde [GitHub](https://github.com) o con el CLI:
#
# ```bash
# gh repo create [usuario]/[nombre-repo] --public --add-readme --clone
# ```
#
# Si lo creas desde la página web, elige un nombre para el repositorio y visibilidad pública.

# %% [markdown]
# ## Agregar al compañero y clonar
#
# Agrega al otro integrante como colaborador desde **Settings → Collaborators → Add people**. Sin este paso, solo el creador del repositorio podrá hacer push.
#
# Si creaste el repositorio con `--clone`, entra a la carpeta creada. Si lo creaste desde la página web, clónalo:
#
# ```bash
# gh repo clone [usuario]/[nombre-repo]
# cd [nombre-repo]
# ```

# %% [markdown]
# ## Crear la rama y copiar archivos
#
# Dentro del repositorio del curso:
#
# ```bash
# git checkout -b lab_1
# ```
#
# Luego:
#
# 1. Crea `labs/lab_1` y copia este notebook, responde las preguntas y guarda la versión completada.
# 2. Copia a la raíz `pyproject.toml`, `README.md`, `.gitignore`, `.pre-commit-config.yaml`, `uv.lock` y la carpeta `.github`.
# 3. Verifica que `.gitignore` incluya `.venv/`.
# 4. Verifica que exista `.github/pull_request_template.md` para que GitHub proponga el template automáticamente.

# %% [markdown]
# ## Plantilla mínima para `README.md`
#
# ```markdown
# # MDS7202 - Laboratorio de Programación Científica para Ciencia de Datos
#
# Repositorio del curso MDS7202 (Otoño 2026), Facultad de Ciencias Físicas y Matemáticas, Universidad de Chile.
#
# ## Integrantes
#
# | Nombre | GitHub |
# |--------|--------|
# | Nombre Apellido 1 | [@usuario1](https://github.com/usuario1) |
# | Nombre Apellido 2 | [@usuario2](https://github.com/usuario2) |
#
# ## Estructura del repositorio
#
# .
# ├── .github/
# │   ├── workflows/
# │   │   └── lint.yml
# │   └── pull_request_template.md
# ├── labs/
# │   ├── lab_1/
# │   └── ...
# ├── pyproject.toml
# ├── .github/
# ├── .pre-commit-config.yaml
# └── README.md
#
# ## Configuración del entorno
#
# uv sync --locked --all-groups
# uv run pre-commit install
# ```

# %% [markdown]
# ## Validar y preparar el commit
#
# Ejecuta las validaciones del entorno:
#
# ```bash
# uv sync --locked --all-groups
# uv run pre-commit install
# uv run pre-commit run --all-files
# uv run ruff check .
# uv run ruff format --check .
# ```
#
# Agrega los archivos y crea un commit Conventional Commits:
#
# ```bash
# git add labs/lab_1 pyproject.toml README.md .gitignore .pre-commit-config.yaml uv.lock .github
# git commit -m "feat: agregar primer laboratorio"
# git push -u origin lab_1
# ```

# %% [markdown]
# ## Crear el Pull Request desde GitHub
#
# Abre el Pull Request desde la interfaz gráfica:
#
# 1. Entra al repositorio del curso.
# 2. Selecciona **Compare & pull request** o **New pull request**.
# 3. Elige `main` como branch base y `lab_1` como branch de trabajo.
# 4. Completa el template que GitHub cargará desde `.github/pull_request_template.md`.
# 5. Usa el título `[Lab 1] Entrega Laboratorio 1`.
# 6. Verifica que el workflow `.github/workflows/lint.yml` pase correctamente.
# 7. Copia el enlace del Pull Request después de crearlo y aprobarlo.

# %% [markdown]
# ### Template Markdown de la descripción
#
# ```markdown
# ## Descripción
#
# <!-- Describe de forma concisa qué cambios introduce este Pull Request y qué problema resuelve. -->
#
# ## Tipo de cambio
#
# - [ ] Feature
# - [ ] Bugfix
# - [ ] Refactor
# - [ ] Documentación
# - [ ] Configuración / Tooling / CI
#
# ## Cambios principales
#
# <!-- Detalla los cambios importantes realizados en este PR. -->
#
# ## Integrantes
#
# - Nombre Apellido 1
# - Nombre Apellido 2
#
# ## Validaciones realizadas
#
# - [ ] `uv sync --locked --all-groups`
# - [ ] `uv run pre-commit run --all-files`
# - [ ] `uv run ruff check .`
# - [ ] `uv run ruff format --check .`
# - [ ] CI pasó correctamente
#
# ## Evidencia o enlaces relevantes
#
# - Notebook:
# - Pull Request:
# ```

# %% [markdown]
# ## Entregables
#
# - Enlace del notebook dentro del repositorio del curso.
# - Enlace del Pull Request final.
# - Integrantes identificados en el README y en la descripción del PR.
# - Evidencia de que `lint.yml` pasó correctamente.
#
# En local, después de que el Pull Request sea integrado, cambia a `main` y actualiza la rama:
#
# ```bash
# git checkout main
# git pull
# ```
#
# Antes de crear una rama para un laboratorio nuevo, parte desde `main` actualizado.

# %% [markdown]
# <!-- IMPORTANTE -->
# <div style="padding:16px 20px; margin:16px 0; border-left:4px solid #8957e5; background:rgba(137,87,229,.12); color:inherit; border-radius:4px;">
#
#   <strong style="display:block; margin-bottom:8px;">📌 Importante</strong>
#   La entrega no consiste solo en que el código funcione: también deben poder explicar qué ocurrió en Git, qué revisó la automatización y por qué eligieron ese flujo de trabajo.
# </div>

# %% [markdown]
# ## Checklist final
#
# <!-- PREGUNTA -->
# <div style="padding:16px 20px; margin:16px 0; border-left:4px solid #58a6ff; background:rgba(88,166,255,.12); color:inherit; border-radius:4px;">
#
#   <strong style="display:block; margin-bottom:8px;">❓ Preguntas</strong>
#   1. ¿Qué es Jupyter y cómo ejecutas un notebook en VS Code?
#   2. ¿Qué es Markdown y cómo se usa en un `README.md`?
#   3. ¿Qué diferencia hay entre Git, GitHub, un repositorio local y un remoto?
#   4. ¿Qué función cumplen el working tree, el staging area, los commits y las branches?
#   5. ¿Qué diferencia hay entre `git fetch`, `git pull` y `git push`?
#   6. ¿Qué son un entorno virtual, `pyproject.toml` y `uv.lock`?
#   7. ¿Qué revisan Ruff, pre-commit y CI?
#   8. ¿Cómo crearías una branch, abrirías un Pull Request desde GitHub y resolverías el conflicto con `origin/fix-ifs`?
# </div>

# %% [markdown]
# <code>Escribe tus respuestas aquí:</code>
# 1. **Jupyter** es un entorno interactivo que permite ejecutar código por celdas, combinando código, resultados y texto explicativo en un mismo documento (`.ipynb`). En VS Code se ejecuta instalando la extensión oficial de Jupyter, abriendo el archivo `.ipynb`, seleccionando el kernel correcto (el entorno Python/`.venv` del proyecto) y luego corriendo las celdas con el botón de "play" o `Shift+Enter`.
# 2. **Markdown** es un lenguaje de marcado ligero que usa símbolos simples (`#`, `**`, `-`, etc.) para dar formato a texto plano sin necesidad de HTML. En un `README.md` se usa para estructurar la documentación del proyecto con títulos, listas, negritas, enlaces e imágenes, ya que GitHub lo renderiza automáticamente como texto formateado al mostrarlo en el repositorio.
# 3. **Git** es el sistema de control de versiones (el software que rastrea cambios en el código); **GitHub** es una plataforma en la nube que aloja repositorios Git y añade funcionalidades colaborativas (PRs, issues, etc.). Un **repositorio local** es la copia del proyecto y su historial en tu propio computador; un **repositorio remoto** es esa misma copia alojada en un servidor (como GitHub), que permite sincronizar cambios entre distintos colaboradores o máquinas.
# 4. El **working tree** es la carpeta de archivos tal como los ves y editas en el disco. El **staging area** (o índice) es un espacio intermedio donde marcas qué cambios específicos quieres incluir en el próximo commit (`git add`). Los **commits** son fotografías guardadas y permanentes del proyecto en un momento dado, con su propio historial. Las **branches** son líneas de desarrollo independientes que permiten trabajar en paralelo sin afectar el código principal hasta que se combinan (merge).
# 5. `git fetch` descarga los cambios del remoto sin mezclarlos con tu trabajo local. `git pull` hace lo mismo pero además los integra automáticamente (`fetch` + `merge`). `git push` hace lo opuesto: envía tus commits locales al repositorio remoto.
# 6. Un **entorno virtual** es una instalación aislada de Python y sus paquetes, independiente del sistema, para evitar conflictos entre proyectos. El **`pyproject.toml`** declara las dependencias y metadatos del proyecto de forma flexible (rangos de versión). El **`uv.lock`** fija las versiones exactas de todas las dependencias (incluidas las transitivas) junto con hashes de integridad, garantizando que el entorno sea idéntico y reproducible en cualquier máquina.
# 7. **Ruff** revisa el código en busca de errores de estilo, malas prácticas y problemas de formato (linting), de forma muy rápida. **pre-commit** ejecuta automáticamente ese tipo de verificaciones (como Ruff) justo antes de que un commit se complete, evitando subir código con errores. **CI** (Integración Continua, vía GitHub Actions) ejecuta esas mismas validaciones —y típicamente también tests— en el servidor cada vez que se sube código o se abre un PR, asegurando que los cambios no rompan el proyecto antes de fusionarlos.
# 8. Se crea una branch nueva desde `main` con `git checkout -b nombre-branch`, se hacen los cambios y commits necesarios, y se sube con `git push -u origin nombre-branch`. Luego, en GitHub, se abre el Pull Request desde la pestaña "Pull requests" → "New pull request", seleccionando esa branch como origen y `main` como destino. Si hay conflicto con `origin/fix-ifs`, se resuelve corriendo `git merge origin/fix-ifs` localmente, editando manualmente los archivos en conflicto para eliminar las marcas (`<<<<<<<`, `=======`, `>>>>>>>`) y quedarse con el código correcto, y finalmente completando con `git add` + `git commit` antes de subir los cambios al PR.

# %% [markdown]
# ## Fin

# %% [markdown]
# Eso ha sido todo por ahora. Esperamos que este laboratorio les haya servido para trabajar con Jupyter, Git y GitHub. Recuerden los días de plazo disponibles y que, ante cualquier duda, pueden contactar al equipo docente.
#
# ¡Nos vemos!
#
# <img src=https://media.tenor.com/OYLdav9k9LkAAAAd/kitty-cat.gif height=300 alt="Gato animado de despedida">

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=9f2f5d63-a7c9-4ca0-abb3-5a34066f442d' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' />
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
